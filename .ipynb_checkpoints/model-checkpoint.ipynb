# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
import os
import cv2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
train = ImageDataGenerator(rescale=1/255)
test = ImageDataGenerator(rescale=1/255)

train_dataset = train.flow_from_directory(r"dataset\train",
                                          target_size=(150,150),
                                          batch_size = 32,
                                          class_mode = 'binary')
                                         
test_dataset = test.flow_from_directory(r"dataset\validation",
                                          target_size=(150,150),
                                          batch_size =32,
                                          class_mode = 'binary')
# Out:
# Found 13839 images belonging to 2 classes.
# Found 593 images belonging to 2 classes.

# %%
model = keras.Sequential()

# Convolutional layer and maxpool layer 1
model.add(keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=(150,150,3)))
model.add(keras.layers.MaxPool2D(2,2))

# Convolutional layer and maxpool layer 2
model.add(keras.layers.Conv2D(64,(3,3),activation='relu'))
model.add(keras.layers.MaxPool2D(2,2))

# Convolutional layer and maxpool layer 3
model.add(keras.layers.Conv2D(128,(3,3),activation='relu'))
model.add(keras.layers.MaxPool2D(2,2))

# Convolutional layer and maxpool layer 4
model.add(keras.layers.Conv2D(128,(3,3),activation='relu'))
model.add(keras.layers.MaxPool2D(2,2))

# This layer flattens the resulting image array to 1D array
model.add(keras.layers.Flatten())

# Hidden layer with 512 neurons and Rectified Linear Unit activation function 
model.add(keras.layers.Dense(512,activation='relu'))

# Output layer with single neuron which gives 0 for Cat or 1 for Dog 
#Here we use sigmoid activation function which makes our model output to lie between 0 and 1
model.add(keras.layers.Dense(1,activation='sigmoid'))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit_generator(train_dataset,
         steps_per_epoch = 250,
         epochs = 3,
         validation_data = test_dataset, shuffle=True)
# Out:
# Epoch 1/3
#  74/250 [=======>......................] - ETA: 2:23 - loss: 0.0048 - accuracy: 0.9974
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-13d3eeb9745d> in <module>
#       2          steps_per_epoch = 250,
#       3          epochs = 3,
# ----> 4          validation_data = test_dataset, shuffle=True)
#
# c:\users\asus\.conda\envs\internship\lib\site-packages\tensorflow\python\util\deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# ...

# %%
from tensorflow.keras.applications import VGG16

conv_base = VGG16(weights='imagenet',
                  include_top=False, 
                  input_shape=(150, 150, 3))

conv_base.summary()
# Out:
# ...
# 58892288/58889256 [==============================] - 2s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
from tensorflow.keras.models import Sequential
#from tensorflow.keras.models import Dense,Flatten
#from tensorflow.keras.models.optimizers import Adam

# %%
resnet_model = Sequential()

pretrained_model= tf.keras.applications.ResNet50(include_top=False,
                   input_shape=(180,180,3),
                   pooling='avg',classes=5,
                   weights='imagenet')
for layer in pretrained_model.layers:
        layer.trainable=False

resnet_model.add(pretrained_model)
# Out:
# ...
# 94773248/94765736 [==============================] - 7s 0us/step
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-51681c4c48c9> in <module>
#       4                    input_shape=(180,180,3),
#       5                    pooling='avg',classes=5,
# ----> 6                    weights='imagenet')
#       7 for layer in pretrained_model.layers:
#       8         layer.trainable=False
#
# c:\users\asus\.conda\envs\internship\lib\site-packages\tensorflow\python\keras\applications\resnet.py in ResNet50(include_top, weights, input_tensor, input_shape, pooling, classes, **kwargs)
#     473
#     474   return ResNet(stack_fn, False, True, 'resnet50', include_top, weights,
# --> 475                 input_tensor, input_shape, pooling, classes, **kwargs)
#     476
#     477
#
# ...

# %%
def predictImage(filename):
    img1 = image.load_img(filename,target_size=(150,150))
    
    plt.imshow(img1)
 
    Y = image.img_to_array(img1)
    
    X = np.expand_dims(Y,axis=0)
    val = model.predict(X)
    print(val)
    if val == 1:
        
        plt.xlabel("DOG",fontsize=30)
        
    
    elif val == 0:
        
        plt.xlabel("CAT",fontsize=30)

# %%
def gen(folder):
    fin = []
    for i in os.listdir(folder):
        if i.startswith("cat"):
            fin.append([0.])
            
        elif i.startswith("dog"):
            fin.append([1.])
    return fin

# %%
def evalu(folder):
    fin = []
    for i in os.listdir(folder):
        img1 = image.load_img(os.path.join(folder,i),target_size=(150,150))
        Y = image.img_to_array(img1)
        X = np.expand_dims(Y,axis=0)
        val = model.predict(X)
        fin.append(val)
    return fin

# %%
cs = gen("train")

# %%
fc = evalu("train")

# %%
len(cs)
# Out:
# 135

# %%
len(fc)
# Out:
# 135

# %%
import numpy as np
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())
    rmse_val = rmse(np.array(d), np.array(p))
    print("rms error is: " + str(rmse_val))

# %%
predictImage("test.jpeg")
# Out:
# [[0.]]

# %%
predictImage("test_2.jpeg")
# Out:
# [[0.]]

# %%
predictImage("test_3.jpg")
# Out:
# [[1.]]

# %%
predictImage("test_4.jpg")
# Out:
# [[1.]]

# %%
model.save_weights("finished.h5")

# %%
print("Evaluate on test data")
# Out:
# Evaluate on test data
# 15/40 [==========>...................] - ETA: 26s - loss: 4.9498 - accuracy: 0.5000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-ac4904b80bd6> in <module>
#       1 print("Evaluate on test data")
# ----> 2 results = model.evaluate(evalu_set, batch_size=32)
#       3 print("test loss, test acc:", results)
#
# c:\users\asus\.conda\envs\internship\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     101   def _method_wrapper(self, *args, **kwargs):
#     102     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 103       return method(self, *args, **kwargs)
#     104
#     105     # Running inside `run_distribute_coordinator` already.
#
# ...
